# %% [markdown]
# <h4 align="right">3rd of February 2020</h4>
# <h1 align="center"> <font color="blue"> <b>
# Neural Networks and Deep Learning (CIE 555)</b></font> </h1>
# <h2 align="center">Lab 2 (part 2): Keras</h2> <br>

# %% [markdown]
# ### Lab out lines:
#
# * Set up your environment for eager execution
# * Define the main ingredients: a Keras model, an optimizer and a loss function
# * Feed data to the training routine
# * Write a simple training loop that does backprop on the model’s weights
# * Make predictions on the test set

# %% [markdown]
# ### <u>**Part 1: Keras**</u>
# Keras is a high-level Deep Learning API that allows you to easily build, train, evaluate
# and execute all sorts of neural networks. Its documentation (or specification) is avail‐
# able at https://keras.io.

# %% [markdown]
# #### Using Keras with eager execution
# Eager execution is a way to train a Keras model without building a graph. Operations return values, not tensors. Consequently, you can inspect what goes in and comes out of an operation simply by printing a variable’s contents. This is an important advantage in model development and debugging.
#
# You can use eager execution with Keras as long as you use the TensorFlow implementation. This guide gives an outline of the workflow by way of a simple example.

# %%
import numpy as np
import tensorflow as tf
tf.enable_eager_execution()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# Enabling eager execution changes how TensorFlow operations behave—now they immediately evaluate and return their values to Python. tf.Tensor objects reference concrete values instead of symbolic handles to nodes in a computational graph. Since there isn't a computational graph to build and run later in a session, it's easy to inspect results using print() or a debugger. Evaluating, printing, and checking tensor values does not break the flow for computing gradients.
#
# Eager execution works nicely with NumPy. NumPy operations accept tf.Tensor arguments. The TensorFlow tf.math operations convert Python objects and NumPy arrays to tf.Tensor objects. The tf.Tensor.numpy method returns the object's value as a NumPy ndarray.

# %%
A = tf.constant([[1, 2], [3, 4]])
B = tf.constant([[5, 6], [7, 8]])

C = tf.matmul(A, B)

# %%
print(C)
print(C.numpy())
# Out:
# tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)
# [[19 22]
#  [43 50]]

# %% [markdown]
# ### <u>Part 2: Building MLP for iris dataset </u>

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# custom iris data loader with batchs
class DataLoader():
    def __init__(self):
        
        # load the iris form sklearn dataset
        iris = load_iris()
        
        # one hotencoding
        enc = OneHotEncoder() 
        
        # To center the data (make it have zero mean and unit standard error), you subtract 
        # the mean and then divide the result by the standard deviation.x′=x−μσ
        # You do that on the training set of data. But then you have to apply the same transformation
        # to your testing set (e.g. in cross-validation), or to newly obtained examples before forecast.
        labels = enc.fit_transform(iris.target.reshape(-1,1)).A.astype(np.float32)
        
        # split your data to test = 0.2 of train and randomize the data points
        xtrain, xtest, ytrain, ytest = train_test_split(iris.data, labels, test_size = 0.2, random_state = 1)
        
        # to class variables
        self.train_data = xtrain
        self.train_labels = np.asarray(ytrain, dtype=np.int32) 
        self.eval_data = xtest
        self.eval_labels = np.asarray(ytest, dtype=np.int32) 

        # orginal labels
        self.eval_labels_ori = np.asarray(enc.inverse_transform(self.eval_labels), dtype=np.int32)
        self.train_labels_ori = np.asarray(enc.inverse_transform(self.train_labels), dtype=np.int32)
    
    def get_batch(self, batch_size):
        # reshape training data to [0 , train_data , batch_size] 
        index = np.random.randint(0, np.shape(self.train_data)[0], batch_size)
        return self.train_data[index, :], self.train_labels[index]

# %%
# Define Multi Layer Perceptron Class
class MLP(tf.keras.Model):
    
    def __init__(self):
        super().__init__()
        # input layer accept inputs and return 5 outputs activated with ReLU 
        self.dense1 = tf.keras.layers.Dense(units=5, activation=tf.nn.relu)
        # hidden layer accept 5 inputs and return 3 outputs activated with softMax
        self.dense2 = tf.keras.layers.Dense(units=3, activation=tf.nn.softmax)
        
    # forward pass     
    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return x
    
    # predict function
    def predict(self, inputs):
        logits = self(inputs)
        return tf.argmax(logits, axis=-1)

# %%
# The seed method is used to initialize the pseudorandom number generator 
# if you provide same seed value before generating random data it will 
# produce the same data and results. 'reproducibility' 
tf.set_random_seed(2)
np.random.seed(2)

# %%
# Set the Hyperparameters
num_batches = 1000
batch_size = 50
learning_rate = 0.001

# %%
# create the MLP model
model = MLP()

# load the data
data_loader = DataLoader()

# select the optimizer and assgin its learning rate
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)

# %%
# define your training loop
for batch_index in range(num_batches):

    # get batch from the loader
    X, y = data_loader.get_batch(batch_size)
    
    # TensorFlow provides the tf.GradientTape API for automatic differentiation 
    # -computing the gradient of a computation with respect to its input variables.
    # Tensorflow "records" all operations executed inside the context of a tf.GradientTape onto a "tape". 
    with tf.GradientTape() as tape:
        
        # (1) forward pass with the data points from the batch we loaded before
        y_logit_pred = model(tf.convert_to_tensor(X))
        
        # (2) calculate the loss
        #     The softmax function outputs a categorical distribution over outputs.
        #     When you compute the cross-entropy over two categorical distributions,
        #     this is called the “cross-entropy loss”
        loss = tf.losses.softmax_cross_entropy(y, y_logit_pred)
        
        # we print the batch num and loss value
        print("batch %d: loss %f" % (batch_index, loss.numpy()))
    # (3) Compute the gradients for a list of variables.
    #     The gradient computation below is not traced, saving memory.
    grads = tape.gradient(loss, model.variables)

    # (4) Ask the optimizer to apply the processed gradients.
    optimizer.apply_gradients(grads_and_vars=zip(grads, model.variables))
# Out:
# batch 0: loss 1.262261
# batch 1: loss 1.186012
# batch 2: loss 1.164775
# batch 3: loss 1.242380
# batch 4: loss 1.220835
# batch 5: loss 1.243268
# batch 6: loss 1.240545
# batch 7: loss 1.124558
# batch 8: loss 1.336698
# batch 9: loss 1.201456
# batch 10: loss 1.258068
# batch 11: loss 1.179017
# batch 12: loss 1.200622
# batch 13: loss 1.159011
# batch 14: loss 1.255297
# batch 15: loss 1.217777
# batch 16: loss 1.233192
# batch 17: loss 1.269191
# batch 18: loss 1.233290
# batch 19: loss 1.245303
# batch 20: loss 1.268214
# batch 21: loss 1.321350
# batch 22: loss 1.261555
# batch 23: loss 1.224177
# batch 24: loss 1.208028
# batch 25: loss 1.117901
# batch 26: loss 1.072644
# batch 27: loss 1.302055
# batch 28: loss 1.251744
# batch 29: loss 1.228238
# batch 30: loss 1.273488
# batch 31: loss 1.288287
# batch 32: loss 1.210652
# batch 33: loss 1.174688
# batch 34: loss 1.238774
# batch 35: loss 1.197765
# batch 36: loss 1.142623
# batch 37: loss 1.163979
# batch 38: loss 1.217734
# batch 39: loss 1.102479
# batch 40: loss 1.159961
# batch 41: loss 1.192984
# batch 42: loss 1.040483
# batch 43: loss 1.127979
# batch 44: loss 1.174523
# batch 45: loss 1.103207
# batch 46: loss 1.178921
# batch 47: loss 1.080199
# batch 48: loss 1.130539
# batch 49: loss 1.182246
# batch 50: loss 1.163679
# batch 51: loss 1.110747
# batch 52: loss 1.056647
# batch 53: loss 1.201195
# batch 54: loss 1.130748
# batch 55: loss 1.081577
# batch 56: loss 1.151657
# batch 57: loss 1.153307
# batch 58: loss 1.141037
# batch 59: loss 1.060613
# batch 60: loss 1.096758
# batch 61: loss 1.068482
# batch 62: loss 1.166242
# batch 63: loss 1.134261
# batch 64: loss 1.018932
# batch 65: loss 1.077642
# batch 66: loss 1.108858
# batch 67: loss 1.052075
# batch 68: loss 1.097913
# batch 69: loss 1.058778
# batch 70: loss 1.151201
# batch 71: loss 1.116728
# batch 72: loss 1.117924
# batch 73: loss 1.073880
# batch 74: loss 1.076236
# batch 75: loss 1.044376
# batch 76: loss 1.088778
# batch 77: loss 1.062789
# batch 78: loss 1.112498
# batch 79: loss 1.060988
# batch 80: loss 1.099045
# batch 81: loss 1.158595
# batch 82: loss 1.046069
# batch 83: loss 1.114545
# batch 84: loss 1.095370
# batch 85: loss 1.061754
# batch 86: loss 1.126076
# batch 87: loss 1.103535
# batch 88: loss 1.054901
# batch 89: loss 1.059002
# batch 90: loss 1.089853
# batch 91: loss 1.055376
# batch 92: loss 1.041685
# batch 93: loss 1.083065
# batch 94: loss 1.088375
# batch 95: loss 1.062622
# batch 96: loss 1.125579
# batch 97: loss 1.058543
# batch 98: loss 1.035358
# batch 99: loss 1.125051
# batch 100: loss 1.060023
# batch 101: loss 1.095987
# batch 102: loss 1.103663
# batch 103: loss 1.006243
# batch 104: loss 1.134548
# batch 105: loss 1.118529
# batch 106: loss 1.095324
# batch 107: loss 1.122168
# batch 108: loss 1.086909
# batch 109: loss 1.019032
# batch 110: loss 1.107186
# batch 111: loss 1.103802
# batch 112: loss 1.052906
# batch 113: loss 1.062303
# batch 114: loss 1.045200
# batch 115: loss 1.058987
# batch 116: loss 1.057486
# batch 117: loss 1.030248
# batch 118: loss 1.127131
# batch 119: loss 1.035559
# batch 120: loss 1.043966
# batch 121: loss 1.063004
# batch 122: loss 1.050553
# batch 123: loss 1.133090
# batch 124: loss 1.115976
# batch 125: loss 1.106388
# batch 126: loss 1.053297
# batch 127: loss 1.017419
# batch 128: loss 1.026418
# batch 129: loss 1.074075
# batch 130: loss 1.047948
# batch 131: loss 1.052128
# batch 132: loss 1.014726
# batch 133: loss 1.009962
# batch 134: loss 1.029925
# batch 135: loss 1.057331
# batch 136: loss 1.085917
# batch 137: loss 0.995244
# batch 138: loss 1.084092
# batch 139: loss 1.049893
# batch 140: loss 1.063005
# batch 141: loss 1.103413
# batch 142: loss 1.059862
# batch 143: loss 1.032260
# batch 144: loss 1.093177
# batch 145: loss 1.094319
# batch 146: loss 1.100014
# batch 147: loss 1.020357
# batch 148: loss 1.114140
# batch 149: loss 1.015429
# batch 150: loss 1.051209
# batch 151: loss 1.072988
# batch 152: loss 1.016352
# batch 153: loss 1.092205
# batch 154: loss 1.094344
# batch 155: loss 1.063959
# batch 156: loss 1.077967
# batch 157: loss 1.048075
# batch 158: loss 1.041602
# batch 159: loss 1.093607
# batch 160: loss 1.086962
# batch 161: loss 1.051383
# batch 162: loss 1.021772
# batch 163: loss 1.021656
# batch 164: loss 1.013837
# batch 165: loss 1.047797
# batch 166: loss 1.030697
# batch 167: loss 1.023332
# batch 168: loss 1.059357
# batch 169: loss 1.048668
# batch 170: loss 0.954433
# batch 171: loss 1.090095
# batch 172: loss 1.028670
# batch 173: loss 1.006408
# batch 174: loss 1.050120
# batch 175: loss 1.018230
# batch 176: loss 0.960927
# batch 177: loss 1.014830
# batch 178: loss 1.093566
# batch 179: loss 1.048449
# batch 180: loss 1.033045
# batch 181: loss 0.953351
# batch 182: loss 1.059393
# batch 183: loss 0.982439
# batch 184: loss 1.024174
# batch 185: loss 1.036684
# batch 186: loss 1.059851
# batch 187: loss 0.925754
# batch 188: loss 1.064960
# batch 189: loss 1.078060
# batch 190: loss 1.053699
# batch 191: loss 1.042619
# batch 192: loss 1.010558
# batch 193: loss 1.061365
# batch 194: loss 1.017867
# batch 195: loss 1.019357
# batch 196: loss 1.011556
# batch 197: loss 1.078031
# batch 198: loss 1.061557
# batch 199: loss 1.005075
# batch 200: loss 1.010280
# batch 201: loss 0.996175
# batch 202: loss 0.993853
# batch 203: loss 0.943195
# batch 204: loss 1.016155
# batch 205: loss 1.028076
# batch 206: loss 0.991452
# batch 207: loss 1.021906
# batch 208: loss 1.022184
# batch 209: loss 1.084669
# batch 210: loss 1.070451
# batch 211: loss 1.040755
# batch 212: loss 1.034709
# batch 213: loss 1.096785
# batch 214: loss 1.011962
# batch 215: loss 1.035766
# batch 216: loss 1.026083
# batch 217: loss 0.970917
# batch 218: loss 0.932384
# batch 219: loss 1.014001
# batch 220: loss 1.004377
# batch 221: loss 1.029126
# batch 222: loss 0.985275
# batch 223: loss 1.020706
# batch 224: loss 1.008172
# batch 225: loss 0.987235
# batch 226: loss 0.956570
# batch 227: loss 1.018129
# batch 228: loss 1.002857
# batch 229: loss 1.038536
# batch 230: loss 0.948766
# batch 231: loss 0.975359
# batch 232: loss 0.988472
# batch 233: loss 0.983044
# batch 234: loss 1.061364
# batch 235: loss 0.978216
# batch 236: loss 0.942027
# batch 237: loss 0.988888
# batch 238: loss 0.973059
# batch 239: loss 0.986082
# batch 240: loss 0.935049
# batch 241: loss 0.996706
# batch 242: loss 0.986977
# batch 243: loss 0.932403
# batch 244: loss 0.968956
# batch 245: loss 0.949004
# batch 246: loss 0.992535
# batch 247: loss 0.986628
# batch 248: loss 0.941472
# batch 249: loss 0.952780
# batch 250: loss 0.961492
# batch 251: loss 0.967311
# batch 252: loss 0.956008
# batch 253: loss 0.908989
# batch 254: loss 0.923413
# batch 255: loss 0.915467
# batch 256: loss 0.966720
# batch 257: loss 0.928893
# batch 258: loss 0.916381
# batch 259: loss 0.905473
# batch 260: loss 0.970914
# batch 261: loss 0.935130
# batch 262: loss 0.928897
# batch 263: loss 0.969255
# batch 264: loss 0.899526
# batch 265: loss 0.892495
# batch 266: loss 0.903014
# batch 267: loss 0.893088
# batch 268: loss 0.892290
# batch 269: loss 0.879120
# batch 270: loss 0.849880
# batch 271: loss 0.937651
# batch 272: loss 0.903216
# batch 273: loss 0.875763
# batch 274: loss 0.947237
# batch 275: loss 0.856301
# batch 276: loss 0.904749
# batch 277: loss 0.858042
# batch 278: loss 0.895675
# batch 279: loss 0.862405
# batch 280: loss 0.907717
# batch 281: loss 0.894451
# batch 282: loss 0.892952
# batch 283: loss 0.918260
# batch 284: loss 0.913529
# batch 285: loss 0.864768
# batch 286: loss 0.940777
# batch 287: loss 0.896033
# batch 288: loss 0.857374
# batch 289: loss 0.892836
# batch 290: loss 0.869075
# batch 291: loss 0.877029
# batch 292: loss 0.862508
# batch 293: loss 0.854137
# batch 294: loss 0.891732
# batch 295: loss 0.922842
# batch 296: loss 0.905815
# batch 297: loss 0.926660
# batch 298: loss 0.868599
# batch 299: loss 0.822827
# batch 300: loss 0.886226
# batch 301: loss 0.848003
# batch 302: loss 0.867751
# batch 303: loss 0.929194
# batch 304: loss 0.866657
# batch 305: loss 0.904355
# batch 306: loss 0.861157
# batch 307: loss 0.895344
# batch 308: loss 0.852654
# batch 309: loss 0.854238
# batch 310: loss 0.800928
# batch 311: loss 0.847053
# batch 312: loss 0.843520
# batch 313: loss 0.890126
# batch 314: loss 0.856303
# batch 315: loss 0.810929
# batch 316: loss 0.873786
# batch 317: loss 0.905145
# batch 318: loss 0.847272
# batch 319: loss 0.834379
# batch 320: loss 0.854429
# batch 321: loss 0.852446
# batch 322: loss 0.894386
# batch 323: loss 0.869624
# batch 324: loss 0.807770
# batch 325: loss 0.843058
# batch 326: loss 0.893901
# batch 327: loss 0.825363
# batch 328: loss 0.844190
# batch 329: loss 0.800162
# batch 330: loss 0.850812
# batch 331: loss 0.844814
# batch 332: loss 0.856587
# batch 333: loss 0.875975
# batch 334: loss 0.837630
# batch 335: loss 0.782299
# batch 336: loss 0.825933
# batch 337: loss 0.827062
# batch 338: loss 0.811002
# batch 339: loss 0.820754
# batch 340: loss 0.865410
# batch 341: loss 0.817806
# batch 342: loss 0.807007
# batch 343: loss 0.813079
# batch 344: loss 0.855827
# batch 345: loss 0.809839
# batch 346: loss 0.807719
# batch 347: loss 0.833581
# batch 348: loss 0.825501
# batch 349: loss 0.855185
# batch 350: loss 0.862520
# batch 351: loss 0.834357
# batch 352: loss 0.819475
# batch 353: loss 0.838173
# batch 354: loss 0.828710
# batch 355: loss 0.821920
# batch 356: loss 0.870175
# batch 357: loss 0.802002
# batch 358: loss 0.827883
# batch 359: loss 0.776601
# batch 360: loss 0.806251
# batch 361: loss 0.819463
# batch 362: loss 0.848366
# batch 363: loss 0.788949
# batch 364: loss 0.771181
# batch 365: loss 0.787131
# batch 366: loss 0.831706
# batch 367: loss 0.807745
# batch 368: loss 0.823459
# batch 369: loss 0.815479
# batch 370: loss 0.816943
# batch 371: loss 0.757994
# batch 372: loss 0.821071
# batch 373: loss 0.825348
# batch 374: loss 0.793023
# batch 375: loss 0.840208
# batch 376: loss 0.818769
# batch 377: loss 0.833630
# batch 378: loss 0.827639
# batch 379: loss 0.809844
# batch 380: loss 0.792044
# batch 381: loss 0.784207
# batch 382: loss 0.803898
# batch 383: loss 0.762977
# batch 384: loss 0.799416
# batch 385: loss 0.780763
# batch 386: loss 0.809165
# batch 387: loss 0.780936
# batch 388: loss 0.852604
# batch 389: loss 0.845205
# batch 390: loss 0.748568
# batch 391: loss 0.800785
# batch 392: loss 0.865474
# batch 393: loss 0.754004
# batch 394: loss 0.812909
# batch 395: loss 0.811818
# batch 396: loss 0.805804
# batch 397: loss 0.813019
# batch 398: loss 0.783500
# batch 399: loss 0.767355
# batch 400: loss 0.820745
# batch 401: loss 0.797705
# batch 402: loss 0.801317
# batch 403: loss 0.822589
# batch 404: loss 0.782277
# batch 405: loss 0.782293
# batch 406: loss 0.776063
# batch 407: loss 0.767882
# batch 408: loss 0.806723
# batch 409: loss 0.781929
# batch 410: loss 0.773377
# batch 411: loss 0.791098
# batch 412: loss 0.809880
# batch 413: loss 0.769710
# batch 414: loss 0.785628
# batch 415: loss 0.812208
# batch 416: loss 0.752505
# batch 417: loss 0.837428
# batch 418: loss 0.788541
# batch 419: loss 0.797632
# batch 420: loss 0.817412
# batch 421: loss 0.776505
# batch 422: loss 0.796894
# batch 423: loss 0.786529
# batch 424: loss 0.803569
# batch 425: loss 0.772137
# batch 426: loss 0.805887
# batch 427: loss 0.762432
# batch 428: loss 0.784312
# batch 429: loss 0.789204
# batch 430: loss 0.795665
# batch 431: loss 0.812713
# batch 432: loss 0.785310
# batch 433: loss 0.792296
# batch 434: loss 0.798807
# batch 435: loss 0.788028
# batch 436: loss 0.764215
# batch 437: loss 0.788320
# batch 438: loss 0.772529
# batch 439: loss 0.764496
# batch 440: loss 0.791837
# batch 441: loss 0.778613
# batch 442: loss 0.817311
# batch 443: loss 0.732684
# batch 444: loss 0.739975
# batch 445: loss 0.754124
# batch 446: loss 0.826141
# batch 447: loss 0.807060
# batch 448: loss 0.788358
# batch 449: loss 0.778361
# batch 450: loss 0.790743
# batch 451: loss 0.787622
# batch 452: loss 0.799372
# batch 453: loss 0.778710
# batch 454: loss 0.815218
# batch 455: loss 0.824321
# batch 456: loss 0.787116
# batch 457: loss 0.785852
# batch 458: loss 0.771201
# batch 459: loss 0.757231
# batch 460: loss 0.770353
# batch 461: loss 0.750296
# batch 462: loss 0.777761
# batch 463: loss 0.801780
# batch 464: loss 0.764424
# batch 465: loss 0.780202
# batch 466: loss 0.751521
# batch 467: loss 0.775040
# batch 468: loss 0.789852
# batch 469: loss 0.740631
# batch 470: loss 0.739920
# batch 471: loss 0.785668
# batch 472: loss 0.786028
# batch 473: loss 0.787976
# batch 474: loss 0.803879
# batch 475: loss 0.767438
# batch 476: loss 0.757849
# batch 477: loss 0.772583
# batch 478: loss 0.782807
# batch 479: loss 0.757410
# batch 480: loss 0.773727
# batch 481: loss 0.748127
# batch 482: loss 0.743544
# batch 483: loss 0.744323
# batch 484: loss 0.829906
# batch 485: loss 0.722383
# batch 486: loss 0.731690
# batch 487: loss 0.751632
# batch 488: loss 0.753656
# batch 489: loss 0.765729
# batch 490: loss 0.713673
# batch 491: loss 0.719323
# batch 492: loss 0.757497
# batch 493: loss 0.734639
# batch 494: loss 0.730181
# batch 495: loss 0.725425
# batch 496: loss 0.775347
# batch 497: loss 0.782109
# batch 498: loss 0.756087
# batch 499: loss 0.720018
# batch 500: loss 0.792444
# batch 501: loss 0.771026
# batch 502: loss 0.742611
# batch 503: loss 0.792235
# batch 504: loss 0.732655
# batch 505: loss 0.703469
# batch 506: loss 0.773523
# batch 507: loss 0.764555
# batch 508: loss 0.772303
# batch 509: loss 0.767237
# batch 510: loss 0.759626
# batch 511: loss 0.757610
# batch 512: loss 0.747186
# batch 513: loss 0.755856
# batch 514: loss 0.734375
# batch 515: loss 0.781172
# batch 516: loss 0.719192
# batch 517: loss 0.725639
# batch 518: loss 0.755989
# batch 519: loss 0.777671
# batch 520: loss 0.717918
# batch 521: loss 0.763573
# batch 522: loss 0.724721
# batch 523: loss 0.777782
# batch 524: loss 0.720786
# batch 525: loss 0.752400
# batch 526: loss 0.741761
# batch 527: loss 0.765636
# batch 528: loss 0.757530
# batch 529: loss 0.780201
# batch 530: loss 0.736733
# batch 531: loss 0.739677
# batch 532: loss 0.805040
# batch 533: loss 0.754967
# batch 534: loss 0.741249
# batch 535: loss 0.730408
# batch 536: loss 0.758578
# batch 537: loss 0.796426
# batch 538: loss 0.736267
# batch 539: loss 0.741329
# batch 540: loss 0.746481
# batch 541: loss 0.742330
# batch 542: loss 0.798965
# batch 543: loss 0.757232
# batch 544: loss 0.765158
# batch 545: loss 0.777436
# batch 546: loss 0.796680
# batch 547: loss 0.752787
# batch 548: loss 0.705233
# batch 549: loss 0.717705
# batch 550: loss 0.764214
# batch 551: loss 0.740128
# batch 552: loss 0.729917
# batch 553: loss 0.741205
# batch 554: loss 0.729836
# batch 555: loss 0.718326
# batch 556: loss 0.772972
# batch 557: loss 0.736202
# batch 558: loss 0.762426
# batch 559: loss 0.731980
# batch 560: loss 0.732963
# batch 561: loss 0.745563
# batch 562: loss 0.734814
# batch 563: loss 0.780826
# batch 564: loss 0.719337
# batch 565: loss 0.785587
# batch 566: loss 0.760442
# batch 567: loss 0.752214
# batch 568: loss 0.753263
# batch 569: loss 0.727552
# batch 570: loss 0.747901
# batch 571: loss 0.740344
# batch 572: loss 0.731135
# batch 573: loss 0.734055
# batch 574: loss 0.772825
# batch 575: loss 0.767559
# batch 576: loss 0.747006
# batch 577: loss 0.747518
# batch 578: loss 0.751014
# batch 579: loss 0.747671
# batch 580: loss 0.740928
# batch 581: loss 0.722985
# batch 582: loss 0.744335
# batch 583: loss 0.726161
# batch 584: loss 0.728150
# batch 585: loss 0.718182
# batch 586: loss 0.716071
# batch 587: loss 0.753825
# batch 588: loss 0.739346
# batch 589: loss 0.727232
# batch 590: loss 0.725045
# batch 591: loss 0.750457
# batch 592: loss 0.765576
# batch 593: loss 0.752833
# batch 594: loss 0.698729
# batch 595: loss 0.731206
# batch 596: loss 0.729168
# batch 597: loss 0.716120
# batch 598: loss 0.753079
# batch 599: loss 0.732174
# batch 600: loss 0.727406
# batch 601: loss 0.741220
# batch 602: loss 0.734674
# batch 603: loss 0.730792
# batch 604: loss 0.736838
# batch 605: loss 0.736721
# batch 606: loss 0.736891
# batch 607: loss 0.733324
# batch 608: loss 0.775756
# batch 609: loss 0.723175
# batch 610: loss 0.782846
# batch 611: loss 0.767695
# batch 612: loss 0.756924
# batch 613: loss 0.728712
# batch 614: loss 0.707485
# batch 615: loss 0.728024
# batch 616: loss 0.706087
# batch 617: loss 0.742094
# batch 618: loss 0.703395
# batch 619: loss 0.736624
# batch 620: loss 0.729821
# batch 621: loss 0.721269
# batch 622: loss 0.710646
# batch 623: loss 0.683060
# batch 624: loss 0.693546
# batch 625: loss 0.752756
# batch 626: loss 0.775021
# batch 627: loss 0.743634
# batch 628: loss 0.741731
# batch 629: loss 0.723075
# batch 630: loss 0.707694
# batch 631: loss 0.759434
# batch 632: loss 0.743039
# batch 633: loss 0.713636
# batch 634: loss 0.701043
# batch 635: loss 0.743564
# batch 636: loss 0.737743
# batch 637: loss 0.762548
# batch 638: loss 0.741581
# batch 639: loss 0.737028
# batch 640: loss 0.689682
# batch 641: loss 0.740968
# batch 642: loss 0.756419
# batch 643: loss 0.744962
# batch 644: loss 0.726728
# batch 645: loss 0.753887
# batch 646: loss 0.693973
# batch 647: loss 0.718914
# batch 648: loss 0.721183
# batch 649: loss 0.761820
# batch 650: loss 0.714705
# batch 651: loss 0.725003
# batch 652: loss 0.688911
# batch 653: loss 0.724043
# batch 654: loss 0.731281
# batch 655: loss 0.692709
# batch 656: loss 0.700726
# batch 657: loss 0.719930
# batch 658: loss 0.729219
# batch 659: loss 0.701411
# batch 660: loss 0.705525
# batch 661: loss 0.711810
# batch 662: loss 0.705885
# batch 663: loss 0.759254
# batch 664: loss 0.746171
# batch 665: loss 0.761565
# batch 666: loss 0.741607
# batch 667: loss 0.705219
# batch 668: loss 0.758449
# batch 669: loss 0.723862
# batch 670: loss 0.733251
# batch 671: loss 0.745356
# batch 672: loss 0.738791
# batch 673: loss 0.739978
# batch 674: loss 0.743990
# batch 675: loss 0.709517
# batch 676: loss 0.719968
# batch 677: loss 0.744168
# batch 678: loss 0.694793
# batch 679: loss 0.702251
# batch 680: loss 0.731676
# batch 681: loss 0.724450
# batch 682: loss 0.729962
# batch 683: loss 0.706081
# batch 684: loss 0.713152
# batch 685: loss 0.721135
# batch 686: loss 0.692883
# batch 687: loss 0.736974
# batch 688: loss 0.715954
# batch 689: loss 0.716824
# batch 690: loss 0.712386
# batch 691: loss 0.727653
# batch 692: loss 0.750586
# batch 693: loss 0.747691
# batch 694: loss 0.721816
# batch 695: loss 0.752202
# batch 696: loss 0.693873
# batch 697: loss 0.745014
# batch 698: loss 0.737829
# batch 699: loss 0.721710
# batch 700: loss 0.727539
# batch 701: loss 0.746363
# batch 702: loss 0.719513
# batch 703: loss 0.726859
# batch 704: loss 0.751248
# batch 705: loss 0.709456
# batch 706: loss 0.722027
# batch 707: loss 0.713583
# batch 708: loss 0.740033
# batch 709: loss 0.690037
# batch 710: loss 0.705011
# batch 711: loss 0.680080
# batch 712: loss 0.726626
# batch 713: loss 0.739807
# batch 714: loss 0.692365
# batch 715: loss 0.712911
# batch 716: loss 0.724260
# batch 717: loss 0.746742
# batch 718: loss 0.734809
# batch 719: loss 0.700326
# batch 720: loss 0.713621
# batch 721: loss 0.727864
# batch 722: loss 0.754921
# batch 723: loss 0.766342
# batch 724: loss 0.669379
# batch 725: loss 0.714694
# batch 726: loss 0.721664
# batch 727: loss 0.690113
# batch 728: loss 0.711839
# batch 729: loss 0.709057
# batch 730: loss 0.694802
# batch 731: loss 0.695326
# batch 732: loss 0.716266
# batch 733: loss 0.728936
# batch 734: loss 0.701313
# batch 735: loss 0.725685
# batch 736: loss 0.723188
# batch 737: loss 0.703763
# batch 738: loss 0.729763
# batch 739: loss 0.691436
# batch 740: loss 0.731976
# batch 741: loss 0.707884
# batch 742: loss 0.692039
# batch 743: loss 0.701788
# batch 744: loss 0.687353
# batch 745: loss 0.735885
# batch 746: loss 0.704030
# batch 747: loss 0.672509
# batch 748: loss 0.712757
# batch 749: loss 0.683557
# batch 750: loss 0.719270
# batch 751: loss 0.720181
# batch 752: loss 0.702853
# batch 753: loss 0.685781
# batch 754: loss 0.764802
# batch 755: loss 0.693731
# batch 756: loss 0.670217
# batch 757: loss 0.700789
# batch 758: loss 0.726395
# batch 759: loss 0.711655
# batch 760: loss 0.687079
# batch 761: loss 0.720236
# batch 762: loss 0.714191
# batch 763: loss 0.705410
# batch 764: loss 0.698473
# batch 765: loss 0.707934
# batch 766: loss 0.694875
# batch 767: loss 0.706827
# batch 768: loss 0.677622
# batch 769: loss 0.713826
# batch 770: loss 0.700361
# batch 771: loss 0.668373
# batch 772: loss 0.658828
# batch 773: loss 0.707608
# batch 774: loss 0.701905
# batch 775: loss 0.691020
# batch 776: loss 0.688375
# batch 777: loss 0.715328
# batch 778: loss 0.724084
# batch 779: loss 0.726097
# batch 780: loss 0.714384
# batch 781: loss 0.689519
# batch 782: loss 0.686200
# batch 783: loss 0.740793
# batch 784: loss 0.665858
# batch 785: loss 0.726189
# batch 786: loss 0.722414
# batch 787: loss 0.692220
# batch 788: loss 0.691278
# batch 789: loss 0.681715
# batch 790: loss 0.692840
# batch 791: loss 0.681165
# batch 792: loss 0.738994
# batch 793: loss 0.721224
# batch 794: loss 0.710801
# batch 795: loss 0.690445
# batch 796: loss 0.694142
# batch 797: loss 0.725590
# batch 798: loss 0.727782
# batch 799: loss 0.709535
# batch 800: loss 0.722309
# batch 801: loss 0.681904
# batch 802: loss 0.696439
# batch 803: loss 0.701542
# batch 804: loss 0.700752
# batch 805: loss 0.701976
# batch 806: loss 0.682317
# batch 807: loss 0.714203
# batch 808: loss 0.687879
# batch 809: loss 0.727488
# batch 810: loss 0.701413
# batch 811: loss 0.687123
# batch 812: loss 0.706297
# batch 813: loss 0.649591
# batch 814: loss 0.711481
# batch 815: loss 0.688836
# batch 816: loss 0.671787
# batch 817: loss 0.739548
# batch 818: loss 0.679439
# batch 819: loss 0.699626
# batch 820: loss 0.709835
# batch 821: loss 0.715129
# batch 822: loss 0.662407
# batch 823: loss 0.718220
# batch 824: loss 0.683817
# batch 825: loss 0.688617
# batch 826: loss 0.690326
# batch 827: loss 0.686757
# batch 828: loss 0.686231
# batch 829: loss 0.706633
# batch 830: loss 0.704215
# batch 831: loss 0.672538
# batch 832: loss 0.687431
# batch 833: loss 0.693323
# batch 834: loss 0.683636
# batch 835: loss 0.731440
# batch 836: loss 0.700821
# batch 837: loss 0.706871
# batch 838: loss 0.697205
# batch 839: loss 0.694004
# batch 840: loss 0.684417
# batch 841: loss 0.707319
# batch 842: loss 0.675188
# batch 843: loss 0.672919
# batch 844: loss 0.676371
# batch 845: loss 0.740498
# batch 846: loss 0.682054
# batch 847: loss 0.693695
# batch 848: loss 0.707604
# batch 849: loss 0.694308
# batch 850: loss 0.708924
# batch 851: loss 0.694080
# batch 852: loss 0.713114
# batch 853: loss 0.695809
# batch 854: loss 0.679688
# batch 855: loss 0.694906
# batch 856: loss 0.665863
# batch 857: loss 0.678331
# batch 858: loss 0.686039
# batch 859: loss 0.702283
# batch 860: loss 0.697893
# batch 861: loss 0.678091
# batch 862: loss 0.674432
# batch 863: loss 0.679402
# batch 864: loss 0.708046
# batch 865: loss 0.661276
# batch 866: loss 0.678970
# batch 867: loss 0.694969
# batch 868: loss 0.681196
# batch 869: loss 0.688044
# batch 870: loss 0.721423
# batch 871: loss 0.675463
# batch 872: loss 0.699091
# batch 873: loss 0.709510
# batch 874: loss 0.689253
# batch 875: loss 0.690700
# batch 876: loss 0.664420
# batch 877: loss 0.681125
# batch 878: loss 0.674684
# batch 879: loss 0.703348
# batch 880: loss 0.652734
# batch 881: loss 0.715396
# batch 882: loss 0.696965
# batch 883: loss 0.694233
# batch 884: loss 0.680501
# batch 885: loss 0.722228
# batch 886: loss 0.686446
# batch 887: loss 0.696333
# batch 888: loss 0.700591
# batch 889: loss 0.661491
# batch 890: loss 0.710448
# batch 891: loss 0.731181
# batch 892: loss 0.686198
# batch 893: loss 0.695320
# batch 894: loss 0.680237
# batch 895: loss 0.690683
# batch 896: loss 0.708272
# batch 897: loss 0.675969
# batch 898: loss 0.681959
# batch 899: loss 0.694359
# batch 900: loss 0.690984
# batch 901: loss 0.678423
# batch 902: loss 0.663602
# batch 903: loss 0.649739
# batch 904: loss 0.659701
# batch 905: loss 0.698205
# batch 906: loss 0.676479
# batch 907: loss 0.707575
# batch 908: loss 0.661748
# batch 909: loss 0.668428
# batch 910: loss 0.662542
# batch 911: loss 0.649709
# batch 912: loss 0.662351
# batch 913: loss 0.690988
# batch 914: loss 0.683872
# batch 915: loss 0.664756
# batch 916: loss 0.639032
# batch 917: loss 0.666283
# batch 918: loss 0.702633
# batch 919: loss 0.699945
# batch 920: loss 0.680946
# batch 921: loss 0.678665
# batch 922: loss 0.680378
# batch 923: loss 0.688503
# batch 924: loss 0.676878
# batch 925: loss 0.675910
# batch 926: loss 0.664980
# batch 927: loss 0.700766
# batch 928: loss 0.686066
# batch 929: loss 0.677169
# batch 930: loss 0.688853
# batch 931: loss 0.663511
# batch 932: loss 0.714074
# batch 933: loss 0.636788
# batch 934: loss 0.678619
# batch 935: loss 0.701247
# batch 936: loss 0.667259
# batch 937: loss 0.685007
# batch 938: loss 0.715978
# batch 939: loss 0.664161
# batch 940: loss 0.670993
# batch 941: loss 0.676260
# batch 942: loss 0.677812
# batch 943: loss 0.691350
# batch 944: loss 0.652810
# batch 945: loss 0.681280
# batch 946: loss 0.701573
# batch 947: loss 0.672256
# batch 948: loss 0.698346
# batch 949: loss 0.672719
# batch 950: loss 0.671730
# batch 951: loss 0.706479
# batch 952: loss 0.717318
# batch 953: loss 0.678113
# batch 954: loss 0.674556
# batch 955: loss 0.670750
# batch 956: loss 0.701990
# batch 957: loss 0.704348
# batch 958: loss 0.686010
# batch 959: loss 0.659281
# batch 960: loss 0.669135
# batch 961: loss 0.661144
# batch 962: loss 0.686960
# batch 963: loss 0.658818
# batch 964: loss 0.671865
# batch 965: loss 0.694435
# batch 966: loss 0.658649
# batch 967: loss 0.676595
# batch 968: loss 0.652459
# batch 969: loss 0.681793
# batch 970: loss 0.671081
# batch 971: loss 0.646071
# batch 972: loss 0.701081
# batch 973: loss 0.655244
# batch 974: loss 0.704234
# batch 975: loss 0.654738
# batch 976: loss 0.683504
# batch 977: loss 0.707305
# batch 978: loss 0.645235
# batch 979: loss 0.677417
# batch 980: loss 0.681983
# batch 981: loss 0.676091
# batch 982: loss 0.683136
# batch 983: loss 0.668528
# batch 984: loss 0.681774
# batch 985: loss 0.681562
# batch 986: loss 0.680768
# batch 987: loss 0.676764
# batch 988: loss 0.654519
# batch 989: loss 0.671828
# batch 990: loss 0.660017
# batch 991: loss 0.674305
# batch 992: loss 0.662386
# batch 993: loss 0.644918
# batch 994: loss 0.641630
# batch 995: loss 0.663890
# batch 996: loss 0.675806
# batch 997: loss 0.670606
# batch 998: loss 0.674283
# batch 999: loss 0.691554

# %%
# load the train samples and calculate its acc 
num_train_samples = np.shape(data_loader.train_labels)[0]
y_pred = model.predict(data_loader.train_data).numpy()
print("train accuracy: %f" % (sum(y_pred == data_loader.train_labels_ori.squeeze()) / num_train_samples))

# load the test samples and calculate its acc 
num_eval_samples = np.shape(data_loader.eval_labels)[0]
y_pred = model.predict(data_loader.eval_data).numpy()
print("test accuracy: %f" % (sum(y_pred == data_loader.eval_labels_ori.squeeze()) / num_eval_samples))
# Out:
# train accuracy: 0.983333
# test accuracy: 0.933333
