# %% [markdown]
# <h4 align="right">30th of March 2020</h4>
# <h1 align="center">Neural Networks and Deep Learning (CIE 555)</h1>
# <h2 align="center">Lab 8: Recurrent Neural Networks</h2>
# <h3 align="center">Part 2: Time Series Analysis</h3><br>

# %% [markdown]
# #Time Series Analysis with LSTM

# %%
import matplotlib.pyplot as plt
import matplotlib as mplt

import pandas as pd  
import numpy as np  
#import tensorflow as tf
from tensorflow.keras.models import Sequential  
from tensorflow.keras.layers import Dense  
from tensorflow.keras.layers import LSTM 
from tensorflow.keras.layers import Dropout

from google.colab import files

# %% [markdown]
# ###Loading Dataset and Visualization

# %%
#Upload file from local drive
files.upload()

#Training data in the period from 01/01/2013 to 31/12/2017
data_train = pd.read_csv(r'AAPL_train.csv')
# Out:
#      <input type="file" id="files-7302fd50-b56e-43ab-8404-dbd69d2724c4" name="files[]" multiple disabled />
#      <output id="result-7302fd50-b56e-43ab-8404-dbd69d2724c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AAPL_train.csv to AAPL_train.csv

# %% [markdown]
# ## Dataset
# The AAPL dataset is a day-by-day values of a stock market in the period from 01/01/2013 to 31/12/2017

# %%
#Visualize data imported from the csv file
data_train.head(3)
# Out:
#          Date       Open       High        Low      Close  Adj Close     Volume
# 0  2012-12-31  72.932854  76.485718  72.714287  76.024284  53.974899  164873100
# 1  2013-01-02  79.117142  79.285713  77.375717  78.432854  55.684914  140129500
# 2  2013-01-03  78.268570  78.524284  77.285713  77.442856  54.982059   88241300

# %%
#Plot data training data
plt.plot(data_train['Open'])
plt.xlabel('Day number #')
plt.ylabel('Apple opening stock price')
# Out:
# Text(0, 0.5, 'Apple opening stock price')

# %% [markdown]
# ###Preprocessing

# %%
#Normalize features
from sklearn.preprocessing import MinMaxScaler 

data_train_open = np.asarray(data_train['Open'].values).reshape(-1,1) #ِAdd second dimension of 1 to be able to use MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))
data_train_open_scaled = scaler.fit_transform(data_train_open)

# %% [markdown]
# We want to predict the open market value at each day in the dataset based on the open values of the previous 60 days. So, each training data point is a list of prediction_period values and its corresponding target value is the value of the day following the prediction period.

# %%
#Preparing training data features and labels
pred_period = 60; # prediction of the next value based on the last pred_period days
xtrain = []  
ytrain = []  
for i in range(pred_period, len(data_train_open_scaled)):  
    xtrain.append(data_train_open_scaled[i-pred_period:i, 0])   
    ytrain.append(data_train_open_scaled[i, 0])

#Converting xtrain and ytrain to numpy arrays    
xtrain, ytrain = np.array(xtrain), np.array(ytrain)
xtrain.shape
# Out:
# (1200, 60)

# %%
#Reshaping xtrain to be accepted by LSTM module
xtrain = xtrain.reshape(-1,pred_period,1)
xtrain.shape
# Out:
# (1200, 60, 1)

# %% [markdown]
# ###Building Model

# %% [markdown]
# * return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence. default = False.
# We set it to true in the LSTM layers followed by other LSTM layers, since we want to pass sequence of data between the layers. However, in the last LSTM layer that is followed by a Dense layer, we set it to false as we want only to pass the final values of the LSTM units. The Dense layer doesn't accept sequences of data.

# %%
#Building the model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(pred_period, 1)))
#model.add(Dropout(0.2))  
model.add(LSTM(units=50, return_sequences=True))
#model.add(Dropout(0.2))  
model.add(LSTM(units=50, return_sequences=True))
#model.add(Dropout(0.2))  
model.add(LSTM(units=50))
#model.add(Dropout(0.2))  
model.add(Dense(units = 1))  

model.compile(optimizer = 'adam', loss = 'mean_squared_error')  

model.fit(xtrain, ytrain, epochs = 100, batch_size = 64)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0528
# Epoch 2/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0073
# Epoch 3/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0026
# Epoch 4/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0021
# Epoch 5/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0021
# Epoch 6/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0020
# Epoch 7/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0020
# Epoch 8/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0019
# Epoch 9/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0019
# Epoch 10/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0017
# Epoch 11/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0017
# Epoch 12/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0016
# Epoch 13/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0016
# Epoch 14/100
# 19/19 [==============================] - 1s 53ms/step - loss: 0.0018
# Epoch 15/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0023
# Epoch 16/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0016
# Epoch 17/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0014
# Epoch 18/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0013
# Epoch 19/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0012
# Epoch 20/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0013
# Epoch 21/100
# 19/19 [==============================] - 1s 53ms/step - loss: 0.0011
# Epoch 22/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0011
# Epoch 23/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0012
# Epoch 24/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0011
# Epoch 25/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0010
# Epoch 26/100
# 19/19 [==============================] - 1s 53ms/step - loss: 9.4779e-04
# Epoch 27/100
# 19/19 [==============================] - 1s 54ms/step - loss: 9.8388e-04
# Epoch 28/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0012
# Epoch 29/100
# 19/19 [==============================] - 1s 54ms/step - loss: 9.9466e-04
# Epoch 30/100
# 19/19 [==============================] - 1s 55ms/step - loss: 9.5944e-04
# Epoch 31/100
# 19/19 [==============================] - 1s 54ms/step - loss: 9.0912e-04
# Epoch 32/100
# 19/19 [==============================] - 1s 54ms/step - loss: 8.7458e-04
# Epoch 33/100
# 19/19 [==============================] - 1s 54ms/step - loss: 9.1851e-04
# Epoch 34/100
# 19/19 [==============================] - 1s 55ms/step - loss: 9.9345e-04
# Epoch 35/100
# 19/19 [==============================] - 1s 54ms/step - loss: 9.4117e-04
# Epoch 36/100
# 19/19 [==============================] - 1s 55ms/step - loss: 8.5918e-04
# Epoch 37/100
# 19/19 [==============================] - 1s 54ms/step - loss: 8.8048e-04
# Epoch 38/100
# 19/19 [==============================] - 1s 53ms/step - loss: 8.3385e-04
# Epoch 39/100
# 19/19 [==============================] - 1s 55ms/step - loss: 8.2864e-04
# Epoch 40/100
# 19/19 [==============================] - 1s 54ms/step - loss: 8.6205e-04
# Epoch 41/100
# 19/19 [==============================] - 1s 55ms/step - loss: 8.0002e-04
# Epoch 42/100
# 19/19 [==============================] - 1s 55ms/step - loss: 7.7569e-04
# Epoch 43/100
# 19/19 [==============================] - 1s 54ms/step - loss: 7.9546e-04
# Epoch 44/100
# 19/19 [==============================] - 1s 54ms/step - loss: 8.1292e-04
# Epoch 45/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0011
# Epoch 46/100
# 19/19 [==============================] - 1s 54ms/step - loss: 8.3042e-04
# Epoch 47/100
# 19/19 [==============================] - 1s 54ms/step - loss: 7.6998e-04
# Epoch 48/100
# 19/19 [==============================] - 1s 55ms/step - loss: 7.3551e-04
# Epoch 49/100
# 19/19 [==============================] - 1s 53ms/step - loss: 7.8563e-04
# Epoch 50/100
# 19/19 [==============================] - 1s 54ms/step - loss: 8.0757e-04
100
# 19/19 [==============================] - 1s 54ms/step - loss: 5.0564e-04
# Epoch 91/100
# 19/19 [==============================] - 1s 53ms/step - loss: 4.5774e-04
# Epoch 92/100
# 19/19 [==============================] - 1s 54ms/step - loss: 5.2138e-04
# Epoch 93/100
# 19/19 [==============================] - 1s 55ms/step - loss: 4.9559e-04
# Epoch 94/100
# 19/19 [==============================] - 1s 54ms/step - loss: 5.3656e-04
# Epoch 95/100
# 19/19 [==============================] - 1s 54ms/step - loss: 5.1172e-04
# Epoch 96/100
# 19/19 [==============================] - 1s 53ms/step - loss: 5.2036e-04
# Epoch 97/100
# 19/19 [==============================] - 1s 53ms/step - loss: 4.1926e-04
# Epoch 98/100
# 19/19 [==============================] - 1s 55ms/step - loss: 4.0569e-04
# Epoch 99/100
# 19/19 [==============================] - 1s 55ms/step - loss: 4.0284e-04
# Epoch 100/100
# 19/19 [==============================] - 1s 53ms/step - loss: 3.9667e-04

# %% [markdown]
# ###Predicting and Visualizing Model's Output of Training Set

# %%
ypred = model.predict(xtrain)

plt.plot(ypred, color='blue', label='Predicted from the model')
plt.plot(ytrain, color='red', label='Ground truth')
plt.xlabel('Day number #')
plt.ylabel('Apple opening stock price')
plt.legend()

# %% [markdown]
# ###Loading Test Data and Preprocessing

# %% [markdown]
# **Exercise1**
#
# Prepare the test data features and labels to be able to feed them into the network.

# %%
#Testing data in the period from 01/01/2018 to 31/01/2018
files.upload()
data_test = pd.read_csv(r'AAPL_test.csv')

train_length = len(data_train_open_scaled)
data_test_open = np.asarray(data_test['Open'].values).reshape(-1,1) #To be able to use MinMaxScaler
scaler2 = MinMaxScaler(feature_range = (0, 1))

## To predict the first value of the test data we need the last pred_period values from the training data 
data_test_open1 = np.concatenate((data_train_open[train_length-60:train_length],data_test_open))
data_test_open_scaled = scaler2.fit_transform(data_test_open1)


################ To be Done #######################################
#Preparing testing data features and labels
xtest = []  
ytest = []  

for i in range(pred_period, len(data_test_open_scaled)):  
    xtest.append(data_test_open_scaled[i-pred_period:i, 0])   
    ytest.append(data_test_open_scaled[i, 0])

#Converting xtrain and ytrain to numpy arrays    
xtest, ytest = np.array(xtest), np.array(ytest)
xtest.shape








################################################################
# Out:
#      <input type="file" id="files-9a44f72b-d3d8-4ff1-ace1-8a3770caa9ea" name="files[]" multiple disabled />
#      <output id="result-9a44f72b-d3d8-4ff1-ace1-8a3770caa9ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AAPL_test.csv to AAPL_test (2).csv
# (20, 60)

# %% [markdown]
# ###Predicting Model Performance over Test Data

# %% [markdown]
# **Exercise2**
#
# predict the values of the test data using our trained model and apply the necessary transformation on the predcitions to compare it with the target values.

# %%
xtest = xtest.reshape(-1,pred_period,1)
xtest.shape
# Out:
# (20, 60, 1)

# %%
############## To be Done ########################
ypred2 = model.predict(xtest)
ypred2 = scaler2.inverse_transform(ypred2)
###############################################
plt.plot(ypred2, color='blue', label='Predicted from the model')
plt.plot(data_test_open, color='red', label='Ground truth')
plt.xlabel('Day number #')
plt.ylabel('Apple opening stock price')
plt.legend()
